# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 2*np.random.rand(100,1)
y = 3 + 4*x + 1.5*np.random.randn(100,1)

# %%
plt.plot(x,y,"bo")
plt.show()

# %%
x_b = np.c_[np.ones((100,1)), x]
print(x_b[:10])
theta = np.linalg.inv(x_b.T @ x_b) @ x_b.T @ y
theta
# Out:
# [[1.         0.16893426]
#  [1.         1.56808716]
#  [1.         0.33155124]
#  [1.         1.70329337]
#  [1.         1.85287581]
#  [1.         1.31052749]
#  [1.         1.43954087]
#  [1.         0.68037   ]
#  [1.         0.99143671]
#  [1.         0.58930855]]
# array([[2.96050745],
#        [4.06955052]])

# %%
x_new = np.array([[0],[2]])
x_new_b = np.c_[np.ones((2,1)), x_new]
y_predict = x_new_b.dot(theta)
y_predict
# Out:
# array([[ 2.96050745],
#        [11.0996085 ]])

# %%
plt.plot(x,y,"bo")
plt.plot(x_new, y_predict, "r-")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x,y)
(model.intercept_, model.coef_)
# Out:
# (array([2.96050745]), array([[4.06955052]]))

# %%
# Out:
# (array([2.73622337]), array([[4.1687228]]))

# %% [markdown]
# # Batch Gradient Descent

# %%
eta = 0.1 
n_iter = 150
m = x.shape[0]

# %%
theta = np.random.randn(2).reshape(2,1)
theta
# Out:
# array([[0.05368134],
#        [0.06335998]])

# %%
j = np.zeros(n_iter)

for i in range(n_iter):
    j[i] = (1/(2*m))* (((x_b @ theta)  - y)**2).sum()
    theta = theta - eta*(1/m * (x_b.T@((x_b @ theta)  - y)))

# %%
plt.plot(np.arange(n_iter),j,"b-")
plt.grid(True)
plt.show()

# %%
theta
# Out:
# array([[2.97940373],
#        [4.05371314]])

# %%
plt.plot(x,y,"bo")
plt.plot(x, theta[0] + theta[1]*x,"r-")
plt.grid(True)
plt.show()
